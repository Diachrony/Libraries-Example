# %%
import pandas as pd

# %%
# if file is csv format, use this:
# df = pd.read_csv('Pi Digit Competition.csv')

# %%
# might need to install openpyxl for this
df = pd.read_excel('Pi Digit Competition.xlsx')

# %%
df = df.set_index('Grade Level')

# %%
df
# Out:
#              2018  2019  2020  2021  2022
# Grade Level
# 6               5     9    15    23    33
# 7               5     9    15    23    33
# 8               7    12    19    28    40
# 9              11    17    25    36    51
# 10             19    28    40    56    77
# 11             23    33    47    65    89
# 12             27    39    55    76   104

# %%
import matplotlib.pyplot as plt

# %%
ax = df.plot()
plt.legend(loc='lower right')
plt.title('Average Digits of Pi')
plt.show()

# %%
import seaborn as sns

# %%
sns.lineplot(data=df).set(title='Average Digits of Pi')
# Out:
# [Text(0.5, 1.0, 'Average Digits of Pi')]
